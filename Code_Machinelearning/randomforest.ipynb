# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
from pathlib import Path
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

# %%
file_path = Path("../Resources/cleaned_data2.csv")
df= pd.read_csv(file_path)

# %%
df['delivery'] = df['transactions'].str.contains('delivery', case=False, na=False)
df['pickup'] = df['transactions'].str.contains('pickup', case=False, na=False)
df['restaurant_reservation'] = df['transactions'].str.contains('restaurant_reservation', case=False, na=False)

# Fill NaN values with False in the new columns
df['delivery'] = df['delivery'].fillna(False)
df['pickup'] = df['pickup'].fillna(False)
df['restaurant_reservation'] = df['restaurant_reservation'].fillna(False)

# %%
def is_success(rating):
    return rating > 3.7

df['success'] = df['rating'].apply(is_success)

df.head()
# Out:
#                        id                                         name  \
# 0  a0IET3_yCFcO36OqGSsisg                          Eataly NYC Flatiron
# 1  zj8Lq1T8KIC5zwFief15jg                          Prince Street Pizza
# 2  16ZnHpuaaBt92XWeJHCC5A                                   Olio e Più
# 3  vyoA8dxwScuMV_AsTcjQcg                        L & B Spumoni Gardens
# 4  22nKUyCIbpnzR6R3_g1ptQ  Carmine's Italian Restaurant - Times Square
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/1UDlnu...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/hN5xKw...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/0UszeE...      False
#
#                                                  url  review_count  rating  \
# 0  https://www.yelp.com/biz/eataly-nyc-flatiron-n...          6102     4.0
# 1  https://www.yelp.com/biz/prince-street-pizza-n...          5031     4.5
# 2  https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          4858     4.5
# 3  https://www.yelp.com/biz/l-and-b-spumoni-garde...          4647     4.0
# 4  https://www.yelp.com/biz/carmines-italian-rest...          4644     4.0
#
#        transactions  price     group_city cuisines   latitude  longitude  \
# 0  delivery, pickup      2  New York City  Italian  40.742101 -73.989922
# 1  delivery, pickup      1  New York City  Italian  40.723088 -73.994530
# 2  delivery, pickup      2  New York City  Italian  40.733798 -73.999774
# 3  delivery, pickup      2  New York City  Italian  40.594715 -73.981316
# 4  delivery, pickup      2  New York City  Italian  40.757498 -73.986653
#
#   state  delivery  pickup  restaurant_reservation  success
# 0    NY      True    True                   False     True
# 1    NY      True    True                   False     True
# 2    NY      True    True                   False     True
# 3    NY      True    True                   False     True
# 4    NY      True    True                   False     True

# %%
y = df['success']
x = df.drop(columns=['rating', 'success', 'image_url', 'url', 'id', 'name'])

# %%
X= x.fillna(0)

# %%
X.head(20)
# Out:
#     is_closed  review_count                              transactions  price  \
# 0       False          6102                          delivery, pickup      2
# 1       False          5031                          delivery, pickup      1
# 2       False          4858                          delivery, pickup      2
# 3       False          4647                          delivery, pickup      2
# 4       False          4644                          delivery, pickup      2
# 5       False          3813                                  delivery      2
# 6       False          3317                          delivery, pickup      2
# 7       False          3314                          delivery, pickup      2
# 8       False          3155                                    pickup      2
# 9       False          3139                          delivery, pickup      3
# 10      False          2912                          delivery, pickup      1
# 11      False          2846                                         0      2
# 12      False          2826                                  delivery      2
# 13      False          2770  restaurant_reservation, delivery, pickup      3
# 14      False          2670                          delivery, pickup      2
# 15      False          2603                          delivery, pickup      4
# 16      False          2600                          delivery, pickup      3
# 17      False          2490                          delivery, pickup      2
# 18      False          2395                          delivery, pickup      2
# 19      False          2359                          delivery, pickup      3
#
#        group_city cuisines   latitude  longitude state  delivery  pickup  \
# 0   New York City  Italian  40.742101 -73.989922    NY      True    True
# 1   New York City  Italian  40.723088 -73.994530    NY      True    True
# 2   New York City  Italian  40.733798 -73.999774    NY      True    True
# 3   New York City  Italian  40.594715 -73.981316    NY      True    True
# 4   New York City  Italian  40.757498 -73.986653    NY      True    True
# 5   New York City  Mexican  40.742255 -74.005958    NY      True   False
# 6   New York City  Mexican  40.722930 -73.994190    NY      True    True
# 7   New York City  Italian  40.704930 -73.933990    NY      True    True
# 8   New York City  Italian  40.722766 -73.996233    NY     False    True
# 9   New York City  Italian  40.760830 -73.989810    NY      True    True
# 10  New York City  Italian  40.732063 -74.003655    NY      True    True
# 11  New York City  Mexican  40.561161 -74.301079    NJ     False   False
# 12  New York City  Mexican  40.757507 -73.987772    NY      True   False
# 13  New York City  Italian  40.772193 -73.955615    NY      True    True
# 14  New York City  Italian  40.759876 -73.986767    NY      True    True
# 15  New York City  Italian  40.732283 -73.999284    NY      True    True
# 16  New York City  Italian  40.756410 -73.985470    NY      True    True
# 17  New York City  Italian  40.758230 -73.988360    NY      True    True
# 18  New York City  Italian  40.729431 -73.984541    NY      True    True
# 19  New York City  Italian  40.733720 -74.005130    NY      True    True
#
#     restaurant_reservation
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# 5                    False
# 6                    False
# 7                    False
# 8                    False
# 9                    False
# 10                   False
# 11                   False
# 12                   False
# 13                    True
# 14                   False
# 15                   False
# 16                   False
# 17                   False
# 18                   False
# 19                   False

# %%
from sklearn import preprocessing
from sklearn import utils

lab = preprocessing.LabelEncoder()
y_transformed = lab.fit_transform(y)

# %%
y_transformed[:10]
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 1, 1, 0], dtype=int64)

# %%
X =pd.get_dummies(X)

# %%
X.dtypes
# Out:
# is_closed          bool
# review_count      int64
# price             int64
# latitude        float64
# longitude       float64
#                  ...
# state_TN           bool
# state_TX           bool
# state_VA           bool
# state_WA           bool
# state_WI           bool
# Length: 119, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_transformed, random_state=42)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)

X_test_scaled = X_scaler.transform(X_test)

# %%
model = RandomForestRegressor(n_estimators= 100, random_state=42)

# %%
model= model.fit(X_train_scaled, y_train)

# %%
predictions = model.predict(X_test_scaled)

# %%
print(predictions)
# Out:
# [0.53 0.76 0.34 ... 0.43 0.85 0.39]

# %%
from sklearn import metrics
import numpy as np


# Calculate error metrics
mae = metrics.mean_absolute_error(y_test, predictions)
mse = metrics.mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)


print('Random Forest Results:')
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# Random Forest Results:
# Mean Absolute Error (MAE): 0.41
# Mean Squared Error (MSE): 0.23
# Root Mean Squared Error (RMSE): 0.48

# %%
class_model = RandomForestClassifier(n_estimators= 500, random_state=42)

# %%
class_model= class_model.fit(X_train_scaled, y_train)

# %%
class_predictions = class_model.predict(X_test_scaled)

# %%
print(classification_report(y_test, class_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61      2892
#            1       0.63      0.65      0.64      2995
#
#     accuracy                           0.63      5887
#    macro avg       0.63      0.62      0.62      5887
# weighted avg       0.63      0.63      0.63      5887
